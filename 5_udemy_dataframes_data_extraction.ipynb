# %%
import pandas as pd

# %%
df = pd.read_csv('jamesbond.csv')
df.head(5)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
## .set_index() and .reset_index() methods

bond = pd.read_csv('jamesbond.csv', index_col='Film')
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
bond = pd.read_csv('jamesbond.csv')

# %%
bond.set_index('Year', inplace=True)

# %%
bond
# Out:
#                                  Film           Actor            Director  \
# Year
# 1962                           Dr. No    Sean Connery       Terence Young
# 1963            From Russia with Love    Sean Connery       Terence Young
# 1964                       Goldfinger    Sean Connery        Guy Hamilton
# 1965                      Thunderball    Sean Connery       Terence Young
# 1967                    Casino Royale     David Niven          Ken Hughes
# 1967              You Only Live Twice    Sean Connery       Lewis Gilbert
# 1969  On Her Majesty's Secret Service  George Lazenby       Peter R. Hunt
# 1971             Diamonds Are Forever    Sean Connery        Guy Hamilton
# 1973                 Live and Let Die     Roger Moore        Guy Hamilton
# 1974      The Man with the Golden Gun     Roger Moore        Guy Hamilton
# 1977             The Spy Who Loved Me     Roger Moore       Lewis Gilbert
# 1979                        Moonraker     Roger Moore       Lewis Gilbert
# ...

# %%
bond.reset_index()

bond.reset_index(drop=True)
bond.reset_index(drop=False, inplace=True)

# %%
bond.set_index('Film', inplace=True)

# %%
bond.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
bond.reset_index(inplace=True)
bond.set_index('Year', inplace=True)

# %%
bond.head(3)
# Out:
#                        Film         Actor       Director  Box Office  Budget  \
# Year
# 1962                 Dr. No  Sean Connery  Terence Young       448.8     7.0
# 1963  From Russia with Love  Sean Connery  Terence Young       543.8    12.6
# 1964             Goldfinger  Sean Connery   Guy Hamilton       820.4    18.6
#
#       Bond Actor Salary
# Year
# 1962                0.6
# 1963                1.6
# 1964                3.2

# %%
# Retrieving rows by index Label with .loc[] accessor
bond = pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc['Goldfinger']
# Out:
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %%
bond.loc['GoldenEye']
# Out:
# Year                            1995
# Actor                 Pierce Brosnan
# Director             Martin Campbell
# Box Office                     518.5
# Budget                          76.9
# Bond Actor Salary                5.1
# Name: GoldenEye, dtype: object

# %%
bond.loc['Casino Royale']
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
bond.loc['Diamonds Are Forever':'From Russia with Love'] # end index point is inclusive
# Out:
#                        Year           Actor       Director  Box Office  \
# Film
# Diamonds Are Forever   1971    Sean Connery   Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan   Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery  Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore      John Glen       449.4
# From Russia with Love  1963    Sean Connery  Terence Young       543.8
#
#                        Budget  Bond Actor Salary
# Film
# Diamonds Are Forever     34.7                5.8
# Die Another Day         154.2               17.9
# Dr. No                    7.0                0.6
# For Your Eyes Only       60.2                NaN
# From Russia with Love    12.6                1.6

# %%
bond.loc['Diamonds Are Forever':'From Russia with Love':2]
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery   Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6

# %%
bond.loc['Thunderball':]
# Out:
#                      Year           Actor            Director  Box Office  \
# Film
# Thunderball          1965    Sean Connery       Terence Young       848.1
# Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode       463.2
# You Only Live Twice  1967    Sean Connery       Lewis Gilbert       514.2
#
#                      Budget  Bond Actor Salary
# Film
# Thunderball            41.9                4.7
# Tomorrow Never Dies   133.9               10.0
# You Only Live Twice    59.9                4.4

# %%
bond.loc[['GoldenEye', 'Octopussy', 'Die Another Day']]
# Out:
#                  Year           Actor         Director  Box Office  Budget  \
# Film
# GoldenEye        1995  Pierce Brosnan  Martin Campbell       518.5    76.9
# Octopussy        1983     Roger Moore        John Glen       373.8    53.9
# Die Another Day  2002  Pierce Brosnan     Lee Tamahori       465.4   154.2
#
#                  Bond Actor Salary
# Film
# GoldenEye                      5.1
# Octopussy                      7.8
# Die Another Day               17.9

# %%
## Retrieve rows by index Position with .iloc accessor

bond.iloc[0]
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# Name: A View to a Kill, dtype: object

# %%
bond.iloc[[15, 20, 3]]
# Out:
#                                  Year           Actor       Director  \
# Film
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# The Man with the Golden Gun      1974     Roger Moore   Guy Hamilton
# Diamonds Are Forever             1971    Sean Connery   Guy Hamilton
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# On Her Majesty's Secret Service       291.5    37.3                0.6
# The Man with the Golden Gun           334.0    27.7                NaN
# Diamonds Are Forever                  442.5    34.7                5.8

# %%
bond.iloc[4:8] # end index point is exclusive
# Out:
#                        Year           Actor       Director  Box Office  \
# Film
# Die Another Day        2002  Pierce Brosnan   Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery  Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore      John Glen       449.4
# From Russia with Love  1963    Sean Connery  Terence Young       543.8
#
#                        Budget  Bond Actor Salary
# Film
# Die Another Day         154.2               17.9
# Dr. No                    7.0                0.6
# For Your Eyes Only       60.2                NaN
# From Russia with Love    12.6                1.6

# %%
## Passing second arguments to the loc and iloc accessors

bond.loc['Moonraker', 'Actor']
bond.loc['Moonraker', ['Director', 'Box Office']]
bond.loc[['Moonraker', 'Dr. No'], ['Director', 'Box Office']]
# Out:
#                 Director  Box Office
# Film
# Moonraker  Lewis Gilbert       535.0
# Dr. No     Terence Young       448.8

# %%
bond.loc['Moonraker', 'Director':'Budget']
# Out:
# Director      Lewis Gilbert
# Box Office              535
# Budget                 91.5
# Name: Moonraker, dtype: object

# %%
bond.loc['Moonraker':'Thunderball', 'Director':]
# Out:
#                                        Director  Box Office  Budget  \
# Film
# Moonraker                         Lewis Gilbert       535.0    91.5
# Never Say Never Again            Irvin Kershner       380.0    86.0
# Octopussy                             John Glen       373.8    53.9
# On Her Majesty's Secret Service   Peter R. Hunt       291.5    37.3
# Quantum of Solace                  Marc Forster       514.2   181.4
# Skyfall                              Sam Mendes       943.5   170.2
# Spectre                              Sam Mendes       726.7   206.3
# The Living Daylights                  John Glen       313.5    68.8
# The Man with the Golden Gun        Guy Hamilton       334.0    27.7
# The Spy Who Loved Me              Lewis Gilbert       533.0    45.1
# The World Is Not Enough           Michael Apted       439.5   158.3
# Thunderball                       Terence Young       848.1    41.9
#
#                                  Bond Actor Salary
# Film
# ...

# %%
bond.iloc[14, 2]
bond.iloc[14, 2:5]
bond.iloc[20:, 3:]
# Out:
#                              Box Office  Budget  Bond Actor Salary
# Film
# The Man with the Golden Gun       334.0    27.7                NaN
# The Spy Who Loved Me              533.0    45.1                NaN
# The World Is Not Enough           439.5   158.3               13.5
# Thunderball                       848.1    41.9                4.7
# Tomorrow Never Dies               463.2   133.9               10.0
# You Only Live Twice               514.2    59.9                4.4

# %%
# set new value for a specific cell or cells in a row

bond.loc['Dr. No', 'Actor'] = 'Sir Sean Connery'

# %%
bond.loc['Dr. No', 'Actor']
# Out:
# 'Sir Sean Connery'

# %%
bond.loc['Dr. No', ['Box Office', 'Budget', 'Bond Actor Salary']]
# Out:
# Box Office           448.8
# Budget                   7
# Bond Actor Salary      0.6
# Name: Dr. No, dtype: object

# %%
bond.loc['Dr. No', ['Box Office', 'Budget', 'Bond Actor Salary']] = [44800000, 7000000, 600000]

# %%
bond.loc['Dr. No', ['Box Office', 'Budget', 'Bond Actor Salary']]
# Out:
# Box Office           4.48e+07
# Budget                  7e+06
# Bond Actor Salary      600000
# Name: Dr. No, dtype: object

# %%
# set multiple values in a dataframe
actor_is_sean_connery = bond['Actor'] == 'Sean Connery'

# %%
# bond[actor_is_sean_connery]['Actor'] = 'Sir Sean Connery' # not a right way to do it

bond.loc[actor_is_sean_connery, 'Actor'] = 'Sir Sean Connery'

# %%
bond.head(10)
# Out:
#                        Year             Actor         Director  Box Office  \
# Film
# A View to a Kill       1985       Roger Moore        John Glen       275.2
# Casino Royale          2006      Daniel Craig  Martin Campbell       581.5
# Casino Royale          1967       David Niven       Ken Hughes       315.0
# Diamonds Are Forever   1971  Sir Sean Connery     Guy Hamilton       442.5
# Die Another Day        2002    Pierce Brosnan     Lee Tamahori       465.4
# Dr. No                 1962  Sir Sean Connery    Terence Young  44800000.0
# For Your Eyes Only     1981       Roger Moore        John Glen       449.4
# From Russia with Love  1963  Sir Sean Connery    Terence Young       543.8
# GoldenEye              1995    Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964  Sir Sean Connery     Guy Hamilton       820.4
#
#                           Budget  Bond Actor Salary
# Film
# A View to a Kill            54.5                9.1
# ...

# %%
## Rename index labels or columns in dataframe

bond.rename(mapper={'GoldenEye': 'Golden Eye', 'The World Is Not Enough': 'Best Bond Movie Ever'})
bond.rename(mapper={'GoldenEye': 'Golden Eye', 'The World Is Not Enough': 'Best Bond Movie Ever'}, axis=0)
bond.rename(mapper={'GoldenEye': 'Golden Eye', 'The World Is Not Enough': 'Best Bond Movie Ever'}, axis='rows')
bond.rename(mapper={'GoldenEye': 'Golden Eye', 'The World Is Not Enough': 'Best Bond Movie Ever'}, axis='index')
# Out:
#                                  Year             Actor            Director  \
# Film
# A View to a Kill                 1985       Roger Moore           John Glen
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971  Sir Sean Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Sir Sean Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Sean Connery       Terence Young
# Golden Eye                       1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Sir Sean Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# ...

# %%
bond.rename(index={'GoldenEye': 'Golden Eye', 'The World Is Not Enough': 'Best Bond Movie Ever'}, inplace=True)

# %%
bond.rename(mapper={'Year': 'Release Date', 'Box Office': 'Revenue'}, axis=1)
bond.rename(mapper={'Year': 'Release Date', 'Box Office': 'Revenue'}, axis='columns')
# Out:
#                                  Release Date             Actor  \
# Film
# A View to a Kill                         1985       Roger Moore
# Casino Royale                            2006      Daniel Craig
# Casino Royale                            1967       David Niven
# Diamonds Are Forever                     1971  Sir Sean Connery
# Die Another Day                          2002    Pierce Brosnan
# Dr. No                                   1962  Sir Sean Connery
# For Your Eyes Only                       1981       Roger Moore
# From Russia with Love                    1963  Sir Sean Connery
# Golden Eye                               1995    Pierce Brosnan
# Goldfinger                               1964  Sir Sean Connery
# Licence to Kill                          1989    Timothy Dalton
# Live and Let Die                         1973       Roger Moore
# Moonraker                                1979       Roger Moore
# Never Say Never Again                    1983  Sir Sean Connery
# ...

# %%
bond.rename(columns={'Year': 'Release Date', 'Box Office': 'Revenue'}, inplace=True)

# %%
bond.columns = ['Year', 'Actor', 'Director', 'Revenue', 'Budget', 'Bond Actor Salary']

# %%
bond.head(1)
# Out:
#                   Year        Actor   Director  Revenue  Budget  \
# Film
# A View to a Kill  1985  Roger Moore  John Glen    275.2    54.5
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1

# %%
# Delete rows or columns from a dataframe

bond.drop(['A View to a Kill', 'Dr. No'])
# Out:
#                                  Year             Actor            Director  \
# Film
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971  Sir Sean Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Sean Connery       Terence Young
# Golden Eye                       1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Sir Sean Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# Live and Let Die                 1973       Roger Moore        Guy Hamilton
# Moonraker                        1979       Roger Moore       Lewis Gilbert
# ...

# %%
bond.drop('Revenue', axis=1)
bond.drop('Revenue', axis='columns')
# Out:
#                                  Year             Actor            Director  \
# Film
# A View to a Kill                 1985       Roger Moore           John Glen
# Casino Royale                    2006      Daniel Craig     Martin Campbell
# Casino Royale                    1967       David Niven          Ken Hughes
# Diamonds Are Forever             1971  Sir Sean Connery        Guy Hamilton
# Die Another Day                  2002    Pierce Brosnan        Lee Tamahori
# Dr. No                           1962  Sir Sean Connery       Terence Young
# For Your Eyes Only               1981       Roger Moore           John Glen
# From Russia with Love            1963  Sir Sean Connery       Terence Young
# Golden Eye                       1995    Pierce Brosnan     Martin Campbell
# Goldfinger                       1964  Sir Sean Connery        Guy Hamilton
# Licence to Kill                  1989    Timothy Dalton           John Glen
# ...

# %%
actor = bond.pop('Actor')

# %%
actor.head(3)
# Out:
# Film
# A View to a Kill     Roger Moore
# Casino Royale       Daniel Craig
# Casino Royale        David Niven
# Name: Actor, dtype: object

# %%
del bond['Director']

# %%
bond.head(3)
# Out:
#                   Year  Revenue  Budget  Bond Actor Salary
# Film
# A View to a Kill  1985    275.2    54.5                9.1
# Casino Royale     2006    581.5   145.3                3.3
# Casino Royale     1967    315.0    85.0                NaN

# %%
## Create a random sample
bond.sample()
# Out:
#                       Year  Revenue  Budget  Bond Actor Salary
# Film
# Diamonds Are Forever  1971    442.5    34.7                5.8

# %%
bond.sample(n=5)
# Out:
#                              Year  Revenue  Budget  Bond Actor Salary
# Film
# The Man with the Golden Gun  1974    334.0    27.7                NaN
# The Spy Who Loved Me         1977    533.0    45.1                NaN
# Diamonds Are Forever         1971    442.5    34.7                5.8
# Quantum of Solace            2008    514.2   181.4                8.1
# Die Another Day              2002    465.4   154.2               17.9

# %%
bond.sample(frac=.10)
# Out:
#                        Year  Revenue  Budget  Bond Actor Salary
# Film
# Never Say Never Again  1983    380.0    86.0                NaN
# The Spy Who Loved Me   1977    533.0    45.1                NaN
# Tomorrow Never Dies    1997    463.2   133.9               10.0

# %%
bond.sample(n=2, axis='columns')
bond.sample(n=2, axis=1)
bond.sample(n=2, axis='index').head(3)
# Out:
#                   Year  Revenue  Budget  Bond Actor Salary
# Film
# A View to a Kill  1985    275.2    54.5                9.1
# Thunderball       1965    848.1    41.9                4.7

# %%
## .nsmallest() and n.largest() method
bond.nlargest(n=3, columns='Revenue')
# Out:
#              Year     Revenue     Budget  Bond Actor Salary
# Film
# Dr. No       1962  44800000.0  7000000.0           600000.0
# Skyfall      2012       943.5      170.2               14.5
# Thunderball  1965       848.1       41.9                4.7

# %%
bond.nsmallest(3, columns='Budget')
# Out:
#                              Year  Revenue  Budget  Bond Actor Salary
# Film
# From Russia with Love        1963    543.8    12.6                1.6
# Goldfinger                   1964    820.4    18.6                3.2
# The Man with the Golden Gun  1974    334.0    27.7                NaN

# %%
bond['Revenue'].nlargest(3)
# Out:
# Film
# Dr. No         44800000.0
# Skyfall             943.5
# Thunderball         848.1
# Name: Revenue, dtype: float64

# %%
bond = pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
## Filtering with WHERE method
mask = bond['Actor'] == 'Sean Connery'

# %%
bond.where(mask)
# Out:
#                                    Year         Actor        Director  \
# Film
# A View to a Kill                    NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Die Another Day                     NaN           NaN             NaN
# Dr. No                           1962.0  Sean Connery   Terence Young
# For Your Eyes Only                  NaN           NaN             NaN
# From Russia with Love            1963.0  Sean Connery   Terence Young
# GoldenEye                           NaN           NaN             NaN
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Licence to Kill                     NaN           NaN             NaN
# Live and Let Die                    NaN           NaN             NaN
# ...

# %%
bond.where(bond['Box Office'] > 800)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# ...

# %%
mask2 = bond['Box Office'] > 800
bond.where(mask & mask2)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# ...

# %%
## Filter a dataframe with the .query() method
bond.columns = [column_name.replace(" ", "_") for column_name in bond.columns]
bond.head(1)
# Out:
#                   Year        Actor   Director  Box_Office  Budget  \
# Film
# A View to a Kill  1985  Roger Moore  John Glen       275.2    54.5
#
#                   Bond_Actor_Salary
# Film
# A View to a Kill                9.1

# %%
bond.query('Actor == "Sean Connery"')
bond.query('Director == "Guy Hamilton"')
bond.query('Box_Office > 600')
# Out:
#              Year         Actor       Director  Box_Office  Budget  \
# Film
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Spectre      2015  Daniel Craig     Sam Mendes       726.7   206.3
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
#
#              Bond_Actor_Salary
# Film
# Goldfinger                 3.2
# Skyfall                   14.5
# Spectre                    NaN
# Thunderball                4.7

# %%
bond.query("Actor == 'Roger Moore' and Director == 'John Glen'")
# Out:
#                     Year        Actor   Director  Box_Office  Budget  \
# Film
# A View to a Kill    1985  Roger Moore  John Glen       275.2    54.5
# For Your Eyes Only  1981  Roger Moore  John Glen       449.4    60.2
# Octopussy           1983  Roger Moore  John Glen       373.8    53.9
#
#                     Bond_Actor_Salary
# Film
# A View to a Kill                  9.1
# For Your Eyes Only                NaN
# Octopussy                         7.8

# %%
bond.query('Actor in ["Timothy Dalton", "George Lazenby"]')
# Out:
#                                  Year           Actor       Director  \
# Film
# Licence to Kill                  1989  Timothy Dalton      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# The Living Daylights             1987  Timothy Dalton      John Glen
#
#                                  Box_Office  Budget  Bond_Actor_Salary
# Film
# Licence to Kill                       250.9    56.7                7.9
# On Her Majesty's Secret Service       291.5    37.3                0.6
# The Living Daylights                  313.5    68.8                5.2

# %%
## A review of the .apply() method on single columns

def convert_to_string_and_add_millions(number):
  return str(number) + ' millions!'

bond['Box_Office'] = bond['Box_Office'].apply(convert_to_string_and_add_millions)

# %%
bond['Budget'] = bond['Budget'].apply(convert_to_string_and_add_millions)

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director       Box_Office  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen  275.2 millions!
# Casino Royale     2006  Daniel Craig  Martin Campbell  581.5 millions!
# Casino Royale     1967   David Niven       Ken Hughes  315.0 millions!
#
#                            Budget  Bond_Actor_Salary
# Film
# A View to a Kill   54.5 millions!                9.1
# Casino Royale     145.3 millions!                3.3
# Casino Royale      85.0 millions!                NaN

# %%
columns = ['Box_Office', 'Budget', 'Bond_Actor_Salary']
for column in columns:
  bond[column] = bond[column].apply(convert_to_string_and_add_millions)

# %%
bond.head(5)
# Out:
#                       Year           Actor         Director  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen
# Casino Royale         2006    Daniel Craig  Martin Campbell
# Casino Royale         1967     David Niven       Ken Hughes
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori
#
#                                      Box_Office                     Budget  \
# Film
# A View to a Kill      275.2 millions! millions!   54.5 millions! millions!
# Casino Royale         581.5 millions! millions!  145.3 millions! millions!
# Casino Royale         315.0 millions! millions!   85.0 millions! millions!
# Diamonds Are Forever  442.5 millions! millions!   34.7 millions! millions!
# Die Another Day       465.4 millions! millions!  154.2 millions! millions!
#
#                      Bond_Actor_Salary
# Film
# A View to a Kill         9.1 millions!
# Casino Royale            3.3 millions!
# ...

# %%
## The .apply() method with row values

bond = pd.read_csv('jamesbond.csv', index_col='Film')
bond.sort_index(inplace=True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
def good_movie(row):
  actor = row[1]
  budget = row[4]

  if actor == 'Pierce Brosnan':
    return 'The Best'
  elif actor == 'Roger Moore' and budget > 40:
    return 'Enjoyable'
  elif budget < 15:
    return 'Very bad'
  else:
    return 'I have no clue'

bond['Comment'] = bond.apply(good_movie, axis='columns')

# %%
bond.head(5)
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary         Comment
# Film
# A View to a Kill        54.5                9.1       Enjoyable
# Casino Royale          145.3                3.3  I have no clue
# Casino Royale           85.0                NaN  I have no clue
# Diamonds Are Forever    34.7                5.8  I have no clue
# Die Another Day        154.2               17.9        The Best

# %%
## The .copy() method
directors = bond['Director']
directors.head(3)
# Out:
# Film
# A View to a Kill          John Glen
# Casino Royale       Martin Campbell
# Casino Royale            Ken Hughes
# Name: Director, dtype: object

# %%
directors['A View to a Kill'] = 'Mr. John Glen'
# Out:
# <ipython-input-94-70a7e07b64da>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directors['A View to a Kill'] = 'Mr. John Glen'

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore    Mr. John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary         Comment
# Film
# A View to a Kill                9.1       Enjoyable
# Casino Royale                   3.3  I have no clue
# Casino Royale                   NaN  I have no clue

# %%
bond_copy = bond.copy()
directors_copy = bond_copy['Director']

# %%
directors_copy['Casino Royale'] = 'Martin Short'
# Out:
# <ipython-input-99-f377d6d84b17>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directors_copy['Casino Royale'] = 'Martin Short'

# %%
bond_copy.head(3)
# Out:
#                   Year         Actor       Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore  Mr. John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig   Martin Short       581.5   145.3
# Casino Royale     1967   David Niven   Martin Short       315.0    85.0
#
#                   Bond Actor Salary         Comment
# Film
# A View to a Kill                9.1       Enjoyable
# Casino Royale                   3.3  I have no clue
# Casino Royale                   NaN  I have no clue
