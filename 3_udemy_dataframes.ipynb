# %%
import pandas as pd

# %%
nba = pd.read_csv('nba.csv')
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
nba.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, ..., 180.0, 'Texas',
#         7730337.0],
#        ['Jae Crowder', 'Boston Celtics', 99.0, ..., 235.0, 'Marquette',
#         6796117.0],
#        ['John Holland', 'Boston Celtics', 30.0, ..., 205.0,
#         'Boston University', nan],
#        ...,
#        ['Tibor Pleiss', 'Utah Jazz', 21.0, ..., 256.0, nan, 2900000.0],
#        ['Jeff Withey', 'Utah Jazz', 24.0, ..., 231.0, 'Kansas', 947276.0],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=object)

# %%
nba.shape
# Out:
# (458, 9)

# %%
print(nba.dtypes, '\n')
print(nba.dtypes.value_counts())
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object
#
# object     5
# float64    4
# dtype: int64

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=458, step=1),
#  Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#         'College', 'Salary'],
#        dtype='object')]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
# Difference between shared methods in Dataframes and Series
revenue = pd.read_csv('revenue.csv', index_col='Date')
revenue
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/16        985          122    499
# 1/2/16        738          788    534
# 1/3/16         14           20    933
# 1/4/16        730          904    885
# 1/5/16        114           71    253
# 1/6/16        936          502    497
# 1/7/16        123          996    115
# 1/8/16        935          492    886
# 1/9/16        846          954    823
# 1/10/16        54          285    216

# %%
s = pd.Series([1, 2, 3])
s
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
print(s.sum())
print(revenue.sum())
# Out:
# 6
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
print(revenue.sum(axis=1))
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
print(revenue.sum(axis='columns'))
print(revenue.sum(axis='index'))
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
## Selecting column from Dataframe
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
nba.Name
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
nba['Name']
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
nba[['Name', 'Team']]
# Out:
#               Name            Team
# 0    Avery Bradley  Boston Celtics
# 1      Jae Crowder  Boston Celtics
# 2     John Holland  Boston Celtics
# 3      R.J. Hunter  Boston Celtics
# 4    Jonas Jerebko  Boston Celtics
# ..             ...             ...
# 453   Shelvin Mack       Utah Jazz
# 454      Raul Neto       Utah Jazz
# 455   Tibor Pleiss       Utah Jazz
# 456    Jeff Withey       Utah Jazz
# 457            NaN             NaN
#
# [458 rows x 2 columns]

# %%
select = ['Name', 'Salary', 'Team']
nba[select]
# Out:
#               Name     Salary            Team
# 0    Avery Bradley  7730337.0  Boston Celtics
# 1      Jae Crowder  6796117.0  Boston Celtics
# 2     John Holland        NaN  Boston Celtics
# 3      R.J. Hunter  1148640.0  Boston Celtics
# 4    Jonas Jerebko  5000000.0  Boston Celtics
# ..             ...        ...             ...
# 453   Shelvin Mack  2433333.0       Utah Jazz
# 454      Raul Neto   900000.0       Utah Jazz
# 455   Tibor Pleiss  2900000.0       Utah Jazz
# 456    Jeff Withey   947276.0       Utah Jazz
# 457            NaN        NaN             NaN
#
# [458 rows x 3 columns]

# %%
## Adding new columns to Dataframe
nba['Sport'] = 'Basketball'
nba['League'] = 'National Basketball Association'

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary       Sport                           League
# ...

# %%
nba.insert(3, column='League Short', value='NBA')
nba
# Out:
#               Name            Team  Number League Short Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0          NBA       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0          NBA       SF  25.0    6-6
# 2     John Holland  Boston Celtics    30.0          NBA       SG  27.0    6-5
# 3      R.J. Hunter  Boston Celtics    28.0          NBA       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0          NBA       PF  29.0   6-10
# ..             ...             ...     ...          ...      ...   ...    ...
# 453   Shelvin Mack       Utah Jazz     8.0          NBA       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0          NBA       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0          NBA        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0          NBA        C  26.0    7-0
# 457            NaN             NaN     NaN          NBA      NaN   NaN    NaN
#
# ...

# %%
## Broadcasting operations
nba['Age'].add(5)
nba['Age'] + 5

nba['Salary'].sub(1000)
nba['Salary'] - 1000

nba['Weight in Kg'] = nba['Weight'].mul(0.453592)

nba['Weight'].div(2)
# Out:
# 0       90.0
# 1      117.5
# 2      102.5
# 3       92.5
# 4      115.5
#        ...
# 453    101.5
# 454     89.5
# 455    128.0
# 456    115.5
# 457      NaN
# Name: Weight, Length: 458, dtype: float64

# %%
nba['Salary in millions'] = nba['Salary'].div(1000000)

# %%
nba
# Out:
#               Name            Team  Number League Short Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0          NBA       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0          NBA       SF  25.0    6-6
# 2     John Holland  Boston Celtics    30.0          NBA       SG  27.0    6-5
# 3      R.J. Hunter  Boston Celtics    28.0          NBA       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0          NBA       PF  29.0   6-10
# ..             ...             ...     ...          ...      ...   ...    ...
# 453   Shelvin Mack       Utah Jazz     8.0          NBA       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0          NBA       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0          NBA        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0          NBA        C  26.0    7-0
# 457            NaN             NaN     NaN          NBA      NaN   NaN    NaN
#
# ...

# %%
# .value_counts() method

nba['Team'].value_counts().head()
# Out:
# New Orleans Pelicans    19
# Memphis Grizzlies       18
# Milwaukee Bucks         16
# New York Knicks         16
# Denver Nuggets          15
# Name: Team, dtype: int64

# %%
nba['Position'].value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      78
# Name: Position, dtype: int64

# %%
nba['Weight in Kg'].value_counts()
# Out:
# 99.790240     29
# 108.862080    28
# 113.398000    26
# 90.718400     25
# 92.986360     22
#               ..
# 76.657048      1
# 115.212368     1
# 110.676448     1
# 83.007336      1
# 126.098576     1
# Name: Weight in Kg, Length: 87, dtype: int64

# %%
nba['Salary'].value_counts()
# Out:
# 947276.0     31
# 845059.0     18
# 525093.0     13
# 981348.0      6
# 1100602.0     5
#              ..
# 1242720.0     1
# 2489530.0     1
# 5103120.0     1
# 9463484.0     1
# 700902.0      1
# Name: Salary, Length: 309, dtype: int64

# %%
## Drop rows with Null values

nba.tail()
# Out:
#              Name       Team  Number League Short Position   Age Height  \
# 453  Shelvin Mack  Utah Jazz     8.0          NBA       PG  26.0    6-3
# 454     Raul Neto  Utah Jazz    25.0          NBA       PG  24.0    6-1
# 455  Tibor Pleiss  Utah Jazz    21.0          NBA        C  26.0    7-3
# 456   Jeff Withey  Utah Jazz    24.0          NBA        C  26.0    7-0
# 457           NaN        NaN     NaN          NBA      NaN   NaN    NaN
#
#      Weight College     Salary       Sport                           League  \
# 453   203.0  Butler  2433333.0  Basketball  National Basketball Association
# 454   179.0     NaN   900000.0  Basketball  National Basketball Association
# 455   256.0     NaN  2900000.0  Basketball  National Basketball Association
# 456   231.0  Kansas   947276.0  Basketball  National Basketball Association
# 457     NaN     NaN        NaN  Basketball  National Basketball Association
#
#      Weight in Kg  Salary in millions
# ...

# %%
nba.dropna(how='all', inplace=True)
nba
# Out:
#               Name            Team  Number League Short Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0          NBA       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0          NBA       SF  25.0    6-6
# 2     John Holland  Boston Celtics    30.0          NBA       SG  27.0    6-5
# 3      R.J. Hunter  Boston Celtics    28.0          NBA       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0          NBA       PF  29.0   6-10
# ..             ...             ...     ...          ...      ...   ...    ...
# 453   Shelvin Mack       Utah Jazz     8.0          NBA       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0          NBA       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0          NBA        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0          NBA        C  26.0    7-0
# 457            NaN             NaN     NaN          NBA      NaN   NaN    NaN
#
# ...

# %%
nba.dropna(axis=1)
# Out:
#     League Short       Sport                           League
# 0            NBA  Basketball  National Basketball Association
# 1            NBA  Basketball  National Basketball Association
# 2            NBA  Basketball  National Basketball Association
# 3            NBA  Basketball  National Basketball Association
# 4            NBA  Basketball  National Basketball Association
# ..           ...         ...                              ...
# 453          NBA  Basketball  National Basketball Association
# 454          NBA  Basketball  National Basketball Association
# 455          NBA  Basketball  National Basketball Association
# 456          NBA  Basketball  National Basketball Association
# 457          NBA  Basketball  National Basketball Association
#
# [458 rows x 3 columns]

# %%
nba.dropna(subset=['Salary'], inplace=True)
nba
# Out:
#               Name            Team  Number League Short Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0          NBA       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0          NBA       SF  25.0    6-6
# 3      R.J. Hunter  Boston Celtics    28.0          NBA       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0          NBA       PF  29.0   6-10
# 5     Amir Johnson  Boston Celtics    90.0          NBA       PF  29.0    6-9
# ..             ...             ...     ...          ...      ...   ...    ...
# 452     Trey Lyles       Utah Jazz    41.0          NBA       PF  20.0   6-10
# 453   Shelvin Mack       Utah Jazz     8.0          NBA       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0          NBA       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0          NBA        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0          NBA        C  26.0    7-0
#
# ...

# %%
## .fillna() method

nba.fillna(0)
# Out:
#               Name            Team  Number League Short Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0          NBA       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0          NBA       SF  25.0    6-6
# 3      R.J. Hunter  Boston Celtics    28.0          NBA       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0          NBA       PF  29.0   6-10
# 5     Amir Johnson  Boston Celtics    90.0          NBA       PF  29.0    6-9
# ..             ...             ...     ...          ...      ...   ...    ...
# 452     Trey Lyles       Utah Jazz    41.0          NBA       PF  20.0   6-10
# 453   Shelvin Mack       Utah Jazz     8.0          NBA       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0          NBA       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0          NBA        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0          NBA        C  26.0    7-0
#
# ...

# %%
nba['Salary'].fillna(value=0, inplace=True)

# %%
nba['College'].fillna(value='No college', inplace=True)
nba
# Out:
#               Name            Team  Number League Short Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0          NBA       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0          NBA       SF  25.0    6-6
# 3      R.J. Hunter  Boston Celtics    28.0          NBA       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0          NBA       PF  29.0   6-10
# 5     Amir Johnson  Boston Celtics    90.0          NBA       PF  29.0    6-9
# ..             ...             ...     ...          ...      ...   ...    ...
# 452     Trey Lyles       Utah Jazz    41.0          NBA       PF  20.0   6-10
# 453   Shelvin Mack       Utah Jazz     8.0          NBA       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0          NBA       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0          NBA        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0          NBA        C  26.0    7-0
#
# ...

# %%
## .astype() method

nba = pd.read_csv('nba.csv').dropna(how='all')
nba['Salary'].fillna(0, inplace=True)
nba['College'].fillna('None', inplace=True)
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba.dtypes
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   457 non-null    object
#  8   Salary    457 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 35.7+ KB

# %%
nba['Salary'] = nba['Salary'].astype('int')
nba['Number'] = nba['Number'].astype('int')
nba['Age'] = nba['Age'].astype('int')
nba['Weight'] = nba['Weight'].astype('int')

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    int32
#  3   Position  457 non-null    object
#  4   Age       457 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    int32
#  7   College   457 non-null    object
#  8   Salary    457 non-null    int32
# dtypes: int32(4), object(5)
# memory usage: 28.6+ KB

# %%
nba['Position'].nunique()
# Out:
# 5

# %%
nba['Position'] = nba['Position'].astype('category')

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    int32
#  3   Position  457 non-null    category
#  4   Age       457 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    int32
#  7   College   457 non-null    object
#  8   Salary    457 non-null    int32
# dtypes: category(1), int32(4), object(4)
# memory usage: 25.6+ KB

# %%
nba['Team'] = nba['Team'].astype('category')
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    category
#  2   Number    457 non-null    int32
#  3   Position  457 non-null    category
#  4   Age       457 non-null    int32
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    int32
#  7   College   457 non-null    object
#  8   Salary    457 non-null    int32
# dtypes: category(2), int32(4), object(3)
# memory usage: 24.0+ KB

# %%
## .sort_values() method

nba.sort_values('Name', ascending=False, inplace=True)
nba
# Out:
#                 Name                    Team  Number Position  Age Height  \
# 237    Zaza Pachulia        Dallas Mavericks      27        C   32   6-11
# 271    Zach Randolph       Memphis Grizzlies      50       PF   34    6-9
# 402      Zach LaVine  Minnesota Timberwolves       8       PG   21    6-5
# 270   Xavier Munford       Memphis Grizzlies      14       PG   24    6-3
# 386  Wilson Chandler          Denver Nuggets      21       SF   29    6-8
# ..               ...                     ...     ...      ...  ...    ...
# 312       Al Horford           Atlanta Hawks      15        C   30   6-10
# 404    Adreian Payne  Minnesota Timberwolves      33       PF   25   6-10
# 328   Aaron Harrison       Charlotte Hornets       9       SG   21    6-6
# 356     Aaron Gordon           Orlando Magic       0       PF   20    6-9
# 152     Aaron Brooks           Chicago Bulls       0       PG   31    6-0
#
#      Weight         College    Salary
# 237     275            None   5200000
# ...

# %%
nba.sort_values('College', na_position='last')
# Out:
#                    Name                  Team  Number Position  Age Height  \
# 266      JaMychal Green     Memphis Grizzlies       0       PF   25    6-9
# 287          Alonzo Gee  New Orleans Pelicans      15       SF   29    6-6
# 180         Mo Williams   Cleveland Cavaliers      52       PG   33    6-1
# 170   Richard Jefferson   Cleveland Cavaliers      24       SF   35    6-7
# 212      Jerryd Bayless       Milwaukee Bucks      19       PG   27    6-3
# ..                  ...                   ...     ...      ...  ...    ...
# 331  Frank Kaminsky III     Charlotte Hornets      44        C   23    7-0
# 145          Duje Dukan      Sacramento Kings      26       PF   24    6-9
# 129           Jon Leuer          Phoenix Suns      30       PF   27   6-10
# 114     Larry Nance Jr.    Los Angeles Lakers       7       PF   23    6-9
# 308          David West     San Antonio Spurs      30       PF   35    6-9
#
#      Weight    College   Salary
# 266     227    Alabama   845059
# ...

# %%
nba.sort_values(['Team', 'Name'])
# Out:
#                 Name                Team  Number Position  Age Height  Weight  \
# 312       Al Horford       Atlanta Hawks      15        C   30   6-10     245
# 318  Dennis Schroder       Atlanta Hawks      17       PG   22    6-1     172
# 323      Jeff Teague       Atlanta Hawks       0       PG   27    6-2     186
# 309    Kent Bazemore       Atlanta Hawks      24       SF   26    6-5     201
# 311     Kirk Hinrich       Atlanta Hawks      12       SG   35    6-4     190
# ..               ...                 ...     ...      ...  ...    ...     ...
# 381  Marcus Thornton  Washington Wizards      15       SF   29    6-4     205
# 376  Markieff Morris  Washington Wizards       5       PF   26   6-10     245
# 375     Nene Hilario  Washington Wizards      42        C   33   6-11     250
# 378  Otto Porter Jr.  Washington Wizards      22       SF   23    6-8     198
# 379   Ramon Sessions  Washington Wizards       7       PG   30    6-3     190
#
#           College    Salary
# ...

# %%
nba.sort_values(['Team', 'Name'], ascending=[True, False])
# Out:
#                  Name                Team  Number Position  Age Height  \
# 322    Walter Tavares       Atlanta Hawks      22        C   24    7-3
# 310  Tim Hardaway Jr.       Atlanta Hawks      10       SG   24    6-6
# 321    Tiago Splitter       Atlanta Hawks      11        C   31   6-11
# 320   Thabo Sefolosha       Atlanta Hawks      25       SF   32    6-7
# 315      Paul Millsap       Atlanta Hawks       4       PF   31    6-8
# ..                ...                 ...     ...      ...  ...    ...
# 374        JJ Hickson  Washington Wizards      21        C   27    6-9
# 380    Garrett Temple  Washington Wizards      17       SG   30    6-6
# 372       Drew Gooden  Washington Wizards      90       PF   34   6-10
# 369      Bradley Beal  Washington Wizards       3       SG   22    6-5
# 368     Alan Anderson  Washington Wizards       6       SG   33    6-6
#
#      Weight               College    Salary
# 322     260                  None   1000000
# ...

# %%
## .sort_index() method

nba.sort_index()
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25    6-2     180
# 1      Jae Crowder  Boston Celtics      99       SF   25    6-6     235
# 2     John Holland  Boston Celtics      30       SG   27    6-5     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22    6-5     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29   6-10     231
# ..             ...             ...     ...      ...  ...    ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20   6-10     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26    6-3     203
# 454      Raul Neto       Utah Jazz      25       PG   24    6-1     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26    7-3     256
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0     231
#
#                College   Salary
# 0                Texas  7730337
# 1            Marquette  6796117
# ...

# %%
## .rank() method

nba['Salary Rank'] = nba['Salary'].rank(ascending=False).astype('int')

# %%
nba
# Out:
#                 Name                    Team  Number Position  Age Height  \
# 237    Zaza Pachulia        Dallas Mavericks      27        C   32   6-11
# 271    Zach Randolph       Memphis Grizzlies      50       PF   34    6-9
# 402      Zach LaVine  Minnesota Timberwolves       8       PG   21    6-5
# 270   Xavier Munford       Memphis Grizzlies      14       PG   24    6-3
# 386  Wilson Chandler          Denver Nuggets      21       SF   29    6-8
# ..               ...                     ...     ...      ...  ...    ...
# 312       Al Horford           Atlanta Hawks      15        C   30   6-10
# 404    Adreian Payne  Minnesota Timberwolves      33       PF   25   6-10
# 328   Aaron Harrison       Charlotte Hornets       9       SG   21    6-6
# 356     Aaron Gordon           Orlando Magic       0       PF   20    6-9
# 152     Aaron Brooks           Chicago Bulls       0       PG   31    6-0
#
#      Weight         College    Salary  Salary Rank
# ...

# %%
nba.sort_values(by='Salary', ascending=False)
# Out:
#                 Name                 Team  Number Position  Age Height  \
# 109      Kobe Bryant   Los Angeles Lakers      24       SF   37    6-6
# 169     LeBron James  Cleveland Cavaliers      23       SF   31    6-8
# 33   Carmelo Anthony      New York Knicks       7       SF   32    6-8
# 251    Dwight Howard      Houston Rockets      12        C   30   6-11
# 339       Chris Bosh           Miami Heat       1       PF   32   6-11
# ..               ...                  ...     ...      ...  ...    ...
# 397     Axel Toupane       Denver Nuggets       6       SG   23    6-7
# 273   Alex Stepheson    Memphis Grizzlies      35       PF   28   6-10
# 269     Ray McCallum    Memphis Grizzlies       5       PG   24    6-3
# 171    Dahntay Jones  Cleveland Cavaliers      30       SG   35    6-6
# 350    Briante Weber           Miami Heat      12       PG   23    6-2
#
#      Weight                College    Salary  Salary Rank
# ...
